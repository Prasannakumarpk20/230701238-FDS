# %%
#230701238
#Prasnnakumar.P
#CSE-D

import matplotlib.pyplot as plt
Names = ['vegan', 'Vegetarian', 'Non vegetarian', 'eggitarian']
Votes = [123, 223, 1000, 111]
COL = ['green', 'yellow', 'red', 'orange']
ex = (0, 0, 0.2, 0)
plt.pie(Votes, labels=Names, colors=COL, explode=ex, autopct='%0.2f%%')
plt.title('FOOD CONSUMERS')
plt.show()
