# %%
#230701238
#Prasnnakumar.P
#CSE-D

import matplotlib.pyplot as plt
Overs=list(range(5,51,5))
Indian_Score=[85, 100, 135, 165, 195, 220, 245, 260, 275, 290]
Srilankan_Score=[60, 80, 115, 140, 170, 200, 230, 240, 250, 270]
plt.title("INDIA Vs SRILANKA")
plt.xlabel("Overs")
plt.ylabel("Score")
plt.plot(Overs,Indian_Score,color="green",label="INDIA")
plt.plot(Overs,Srilankan_Score,color="red",label="SRILANKA")
plt.legend(loc="center right")
