# %%
#230701238
#Prasnnakumar.P
#CSE-D


import pandas as pd
import matplotlib.pyplot as plt

data = {'Year': list(range(2000, 2011)),
        'Job Postings': [122, 234, 423, 646, 800, 1200, 1645, 2100, 2500, 3200, 5200]}

df = pd.DataFrame(data)

plt.plot(df['Year'], df['Job Postings'], marker='.')
plt.title('Trend of Data Science Job Postings')
plt.xlabel('Year')
plt.ylabel('Number of Job Postings')
plt.show()
